# %%
import crested
meme_db, motif_to_tf_file = crested.get_motif_db()
# Out:
# 2025-08-07 12:53:46.770058: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-07 12:53:46.786636: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754596426.805665  591093 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754596426.811374  591093 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-07 12:53:46.830189: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
os.environ["PATH"] = "/home/niklas.kempynck/meme/bin:" + os.environ["PATH"]

# %%
# run tfmodisco on the contribution scores
crested.tl.modisco.tfmodisco(
    window=1000,
    output_dir="/allen/programs/celltypes/workgroups/rnaseqanalysis/EvoGen/OCTO/aibs-octo-dnaseq-modeling/basal-ganglia/data/human/patterns/modisco_results_ft_500/",
    contrib_dir="/allen/programs/celltypes/workgroups/rnaseqanalysis/EvoGen/OCTO/aibs-octo-dnaseq-modeling/basal-ganglia/data/human/patterns/modisco_results_ft_500/",
    report=True,  # Optional, will match patterns to motif MEME database
    meme_db=meme_db,  # File to MEME database
    max_seqlets=20000,
)
# Out:
# 2025-08-07T12:54:02.712239-0700 INFO No class names provided, using all found in the contribution directory: ['STR-BF_TAC3-PLPP4-LHX8_GABA', 'STRv_D2_MSN', 'Monocyte', 'GPin-BF_Cholinergic_GABA', 'BF_SKOR1_Glut', 'STR_LYPD6-RSPO2_GABA', 'ImOligo', 'VIP_GABA', 'STRd_D2_Matrix_MSN', 'SN_SEMA5A_GABA', 'STRd_D1_Matrix_MSN', 'STR_D1D2_Hybrid_MSN', 'STR_TAC3-PLPP4_GABA', 'STRd_D2_Striosome_MSN', 'ZI-HTH_GABA', 'Microglia', 'Astrocyte', 'B_cells', 'LAMP5-LHX6_GABA', 'STR_FS_PTHLH-PVALB_GABA', 'Pericyte', 'STRd_Cholinergic_GABA', 'OPC', 'Oligo_PLEKHG1', 'Ependymal', 'OT_D1_ICj', 'STRd_D1_Striosome_MSN', 'Endo', 'GPi_Shell', 'GPe_MEIS2-SOX6_GABA', 'SN-VTR_CALB1_Dopa', 'GPe-NDB-SI_LHX6-LHX8-GBX1_GABA', 'SN-VTR-HTH_GATA3-TCF7L2_GABA', 'AMY-SLEA-BNST_GABA', 'STRd_D2_StrioMat_Hybrid_MSN', 'ImAstro', 'SN-VTR_GAD2_Dopa', 'AMY-SLEA-BNST_D1_GABA', 'GPe_SOX6-CTXND1_GABA', 'LAMP5-CXCL14_GABA', 'VLMC', 'STRv_D1_MSN', 'SN_SOX6_Dopa', 'Oligo_OPALIN', 'OB_Dopa-GABA', 'STR_Cholinergic_GABA', 'STRv_D1_NUDAP_MSN', 'STR_SST-CHODL_GABA', 'VTR-HTH_Glut', 'OB_FRMD7_GABA', 'GPi_Core', 'STH_PVALB-PITX2_Glut', 'COP', 'BAM', 'STR_SST-ADARB2_GABA', 'T_cells', 'SN_EBF2_GABA', 'STR_SST-RSPO2_GABA', 'SMC']
# 2025-08-07T12:54:02.919119-0700 INFO Running modisco for class: STR-BF_TAC3-PLPP4-LHX8_GABA
# Using 3821 positive seqlets

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 test
#
# NameError: name 'test' is not defined
