# %%
import crested
meme_db, motif_to_tf_file = crested.get_motif_db()
# Out:
# 2025-08-07 13:00:40.299640: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-07 13:00:40.321756: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754596840.347676  591764 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754596840.355807  591764 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-07 13:00:40.381278: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
os.environ["PATH"] = "/home/niklas.kempynck/meme/bin:" + os.environ["PATH"]

# %%
# run tfmodisco on the contribution scores
crested.tl.modisco.tfmodisco(
    window=1000,
    output_dir="/allen/programs/celltypes/workgroups/rnaseqanalysis/EvoGen/OCTO/aibs-octo-dnaseq-modeling/basal-ganglia/data/human/patterns/modisco_results_ft_500/",
    contrib_dir="/allen/programs/celltypes/workgroups/rnaseqanalysis/EvoGen/OCTO/aibs-octo-dnaseq-modeling/basal-ganglia/data/human/patterns/modisco_results_ft_500/",
    report=True,  # Optional, will match patterns to motif MEME database
    meme_db=meme_db,  # File to MEME database
    max_seqlets=20000,
)
# Out:
# 2025-08-07T13:00:53.575106-0700 INFO No class names provided, using all found in the contribution directory: ['AMY-SLEA-BNST_D1_GABA', 'Monocyte', 'STR_Cholinergic_GABA', 'GPi_Core', 'BAM', 'AMY-SLEA-BNST_GABA', 'GPe_MEIS2-SOX6_GABA', 'STRd_D2_StrioMat_Hybrid_MSN', 'SN_SOX6_Dopa', 'BF_SKOR1_Glut', 'Astrocyte', 'Oligo_OPALIN', 'T_cells', 'STRd_D2_Striosome_MSN', 'OT_D1_ICj', 'SN-VTR_GAD2_Dopa', 'STRv_D1_NUDAP_MSN', 'STR_D1D2_Hybrid_MSN', 'STRd_D2_Matrix_MSN', 'VLMC', 'STR_FS_PTHLH-PVALB_GABA', 'Ependymal', 'STRd_Cholinergic_GABA', 'OPC', 'STR_LYPD6-RSPO2_GABA', 'STRd_D1_Striosome_MSN', 'SMC', 'STRv_D1_MSN', 'STH_PVALB-PITX2_Glut', 'GPe-NDB-SI_LHX6-LHX8-GBX1_GABA', 'ImOligo', 'VTR-HTH_Glut', 'Oligo_PLEKHG1', 'STRv_D2_MSN', 'VIP_GABA', 'STR-BF_TAC3-PLPP4-LHX8_GABA', 'Pericyte', 'STR_SST-CHODL_GABA', 'ImAstro', 'LAMP5-LHX6_GABA', 'STR_SST-RSPO2_GABA', 'SN-VTR_CALB1_Dopa', 'SN_EBF2_GABA', 'B_cells', 'Endo', 'SN_SEMA5A_GABA', 'SN-VTR-HTH_GATA3-TCF7L2_GABA', 'ZI-HTH_GABA', 'GPi_Shell', 'GPe_SOX6-CTXND1_GABA', 'STR_TAC3-PLPP4_GABA', 'STRd_D1_Matrix_MSN', 'OB_FRMD7_GABA', 'Microglia', 'COP', 'STR_SST-ADARB2_GABA', 'GPin-BF_Cholinergic_GABA', 'OB_Dopa-GABA', 'LAMP5-CXCL14_GABA']
# 2025-08-07T13:00:54.042358-0700 INFO Running modisco for class: AMY-SLEA-BNST_D1_GABA
# Using 4199 positive seqlets

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 test
#
# NameError: name 'test' is not defined
